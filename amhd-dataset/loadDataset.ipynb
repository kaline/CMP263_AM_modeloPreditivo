# %% [markdown]
# Etapas
#
# 1. Exploração dos dados - https://colab.research.google.com/github/Tanu-N-Prabhu/Python/blob/master/Exploratory_data_Analysis.ipynb#scrollTo=1wHW41whURub

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 1. Loading the dataset into dataframe

# %%
readAmhd = pd.read_csv('/home/kaline/workspace/CMP263_AM_modeloPreditivo/mental-conditions-syns.csv') 
readAmhd.head()
# Out:
#                              add                        anxiety  \
# 0                            adhd              anxiety disorder
# 1                        a.d.h.d.  generalized anxiety disorder
# 2                           ad/hd                 social phobia
# 3  add attention deficit disorder                social anxiety
# 4                        add/adhd   separation anxiety disorder
#
#                      autism                     bipolar           depression  \
# 0  autism spectrum disorder            bipolar disorder  clinical depression
# 1                 aspergers                 cyclothymia    severe depression
# 2                  autistic                cyclophrenia     major depression
# 3                apserger's  affective bipolar disorder  depressive disorder
# 4        apsergers syndrome        alternating insanity            dysthymia
#
#          eating disorder                              ocd  \
# ...

# %%
readAmhd.describe()
# Out:
#         add            anxiety                    autism           bipolar  \
# count     49                47                        79                65
# unique    48                41                        76                62
# top     adhd  anxiety disorder  autism spectrum disorder  bipolar disorder
# freq       2                 2                         2                 2
#
#                  depression eating disorder                            ocd  \
# count                    76              33                             29
# unique                   70              29                             28
# top     clinical depression        anorexia  obsessive-compulsive disorder
# freq                      2               2                              2
#
#                                   ptsd  schizophrenia
# count                               24             26
# unique                              23             25
# ...

# %%
readAmhd.tail(5)
# Out:
#     add  anxiety                             autism bipolar  \
# 74   NaN     NaN                  kanner's syndrome     NaN
# 75   NaN     NaN                   kannerian autism     NaN
# 76   NaN     NaN                   kanners syndrome     NaN
# 77   NaN     NaN                        nonautistic     NaN
# 78   NaN     NaN  pervasive developmental disorders     NaN
#
#                       depression eating disorder  ocd ptsd schizophrenia
# 74  unipolar depressive disorder             NaN  NaN  NaN           NaN
# 75     unipolar major depression             NaN  NaN  NaN           NaN
# 76                           NaN             NaN  NaN  NaN           NaN
# 77                           NaN             NaN  NaN  NaN           NaN
# 78                           NaN             NaN  NaN  NaN           NaN

# %% [markdown]
# # 3. Checking the types of data

# %%
readAmhd.dtypes
# Out:
#  add               object
# anxiety            object
# autism             object
# bipolar            object
# depression         object
# eating disorder    object
# ocd                object
# ptsd               object
# schizophrenia      object
# dtype: object

# %%
readAmhd = readAmhd.rename(columns={"add":"adhd","anxiety":"anxiety", "autism":"", "bipolar":"", "depression":"", "eating":"", "disorder":"",	"ocd":"", "ptsd":"", "schizophrenia":""})
readAmhd.head()
# Out:
#                               adh                                \
# 0                            adhd              anxiety disorder
# 1                        a.d.h.d.  generalized anxiety disorder
# 2                           ad/hd                 social phobia
# 3  add attention deficit disorder                social anxiety
# 4                        add/adhd   separation anxiety disorder
#
#                                                                               \
# 0  autism spectrum disorder            bipolar disorder  clinical depression
# 1                 aspergers                 cyclothymia    severe depression
# 2                  autistic                cyclophrenia     major depression
# 3                apserger's  affective bipolar disorder  depressive disorder
# 4        apsergers syndrome        alternating insanity            dysthymia
#
#          eating disorder                                   \
# ...
